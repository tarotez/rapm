# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt

data = np.random.rand(301) - 0.5
ps = np.abs(np.fft.fft(data))**2

time_step = 1 / 30
freqs = np.fft.fftfreq(data.size, time_step)
idx = np.argsort(freqs)

plt.plot(freqs[idx], ps[idx])

# %%
# %matplotlib inline

# %%
data.size
# Out:
# 301

# %%
import numpy as np
import matplotlib.pyplot as plt


sinc = np.array(sin_arr)

samplingFreq = 128
wsize = samplingFreq * wsizeInSec   # window size. data is sampled at 128 Hz, so 1280 sample points = 10 sec.

ps = np.abs(np.fft.fft(eeg[stime:etime])) ** 2
power_arr = np.append(power_ar, ps, axis = 0)
stime = etime

time_step = 1 / samplingFreq
freqs = np.fft.fftfreq(power_arr.shape[1], d = time_step)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-22a255aa84cd> in <module>()
#       3
#       4
# ----> 5 sinc = np.array(sin_arr)
#       6
#       7 samplingFreq = 128
#
# NameError: name 'sin_arr' is not defined

# %%
sin(np.arange(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b5695405ac78> in <module>()
# ----> 1 sin(np.arange(10))
#
# NameError: name 'sin' is not defined

# %%
plt.plot(sinc)
